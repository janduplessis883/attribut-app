# %%
import pandas as pd
from notionhelper import NotionHelper
nh = NotionHelper()

# %%
database_id = "191fdfd68a978033a694e08f12f03699"

# %%
nh.get_all_pages_as_json(database_id)
# Out:
# [{'Deadline': {'id': '%3AHny',
#    'type': 'date',
#    'date': {'start': '2025-02-04', 'end': None, 'time_zone': None}},
#   'Status': {'id': '%3DIS%60',
#    'type': 'status',
#    'status': {'id': 'de0e8582-3645-4148-962c-315509313af8',
#     'name': 'Not started',
#     'color': 'default'}},
#   'Duration': {'id': 'SeCH', 'type': 'number', 'number': 30},
#   'Scheduled Time': {'id': 'TgV%3F',
#    'type': 'date',
#    'date': {'start': '2025-02-04T15:00:00.000+00:00',
#     'end': '2025-02-04T15:30:00.000+00:00',
#     'time_zone': None}},
#   'Priority': {'id': 'zyK%3A',
#    'type': 'select',
#    'select': {'id': 'O~xt', 'name': 'High', 'color': 'red'}},
#   'Name': {'id': 'title',
#    'type': 'title',
#    'title': [{'type': 'text',
#      'text': {'content': 'MEETING', 'link': None},
#      'annotations': {'bold': False,
#       'italic': False,
#       'strikethrough': False,
#       'underline': False,
#       'code': False,
#       'color': 'default'},
# ...

# %%
nh.get_all_page_ids(database_id)

# %%
nh.notion_get_page('191fdfd68a978033a694e08f12f03699')
# Out:
# {'Deadline': {'id': '%3AHny', 'type': 'date', 'date': {'start': '2025-02-06T16:00:00.000+00:00', 'end': None, 'time_zone': None}}, 'Status': {'id': '%3DIS%60', 'type': 'status', 'status': {'id': 'de0e8582-3645-4148-962c-315509313af8', 'name': 'Not started', 'color': 'default'}}, 'Recurring Interval': {'id': '%3EM%3Cn', 'type': 'number', 'number': None}, 'Duration': {'id': 'SeCH', 'type': 'number', 'number': 10}, 'Scheduled Time': {'id': 'TgV%3F', 'type': 'date', 'date': {'start': '2025-02-05', 'end': None, 'time_zone': None}}, 'Created time': {'id': 'VxLr', 'type': 'created_time', 'created_time': '2025-02-05T10:50:00.000Z'}, 'Priority': {'id': 'zyK%3A', 'type': 'select', 'select': {'id': 'O~xt', 'name': 'High', 'color': 'red'}}, 'Name': {'id': 'title', 'type': 'title', 'title': [{'type': 'text', 'text': {'content': 'Book Learning Difficulties review with GPs', 'link': None}, 'annotations': {'bold': False, 'italic': False, 'strikethrough': False, 'underline': False, 'code': False, 'co
# ...
